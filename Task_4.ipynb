# %% [markdown]
# <a href="https://colab.research.google.com/github/NataliaLak/Pandas/blob/main/Task_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
house = pd.read_csv("kc_house_data (1).csv", encoding="latin-1")
house.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
house.shape
# Out:
# (21613, 21)

# %%
df = pd.read_csv("laptop_price (3).csv", encoding="latin-1")
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %% [markdown]
# ##Задача 1
#
#  - Постройте график
#
#  - Назовите график
#
#  - Сделайте именование оси x и оси y
#
#  - Сделайте выводы

# %% [markdown]
# 1.2. Изучите стоимости недвижимости

# %%
house.price.min()
# Out:
# 75000.0

# %%
house.price.max()
# Out:
# 7700000.0

# %%
house.price.median()
# Out:
# 450000.0

# %%
house.price.value_counts()
# Out:
# 350000.0     172
# 450000.0     172
# 550000.0     159
# 500000.0     152
# 425000.0     150
#             ...
# 607010.0       1
# 1362500.0      1
# 298800.0       1
# 957500.0       1
# 402101.0       1
# Name: price, Length: 4028, dtype: int64

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
plt.figure(figsize=(12, 6))
plt.hist(house['price'])
plt.title('Cтоимость недвижимости')
plt.xlabel('стоимость')
plt.ylabel('Количество');

# %% [markdown]
# Исходя из данных можно увидеть, что наибольшее количество домов в ценовом диапазоне от 100 000 до 800 000.

# %% [markdown]
# 1.3. Изучите распределение квадратуры жилой

# %%
house.sqft_living.min()
# Out:
# 290

# %%
house.sqft_living.max()
# Out:
# 13540

# %%
sns.set_theme(style="whitegrid")

plt.figure(figsize=(6, 4))
plt.hist(house['sqft_living'], bins=10)
plt.title('Распределение жилой квадратуры')
plt.xlabel('Жилая квадратура')
plt.ylabel('Количесво');

# %% [markdown]
# Наибольшее количество домов с жилой квадратурой 180-300 м, на втором месте недвижимось с маленькой квадратурой от 20 до 180 м.

# %% [markdown]
# 1.4. Изучите распределение года постройки

# %%
house.yr_built.min()
# Out:
# 1900

# %%
house.yr_built.max()
# Out:
# 2015

# %%
sns.set_theme(style="darkgrid")

plt.figure(figsize=(6, 4))
plt.hist(house['yr_built'], bins=10)
plt.title('Анализ распределения года постройки')
plt.xlabel('Год постройки')
plt.ylabel('Количесво');

# %% [markdown]
# Наибольшее число домов построено в период с 1945 по 2015 год. Пик постройки пришёлся на 2005 - 2015 гг.

# %% [markdown]
# ## 2 задача
#
# 2.1. Изучите распределение домов от наличия вида на набережную
#
# Постройте график
#
# Сделайте выводы

# %%
view1 = house.view.value_counts()
view1.head()
# Out:
# 0    19489
# 2      963
# 3      510
# 1      332
# 4      319
# Name: view, dtype: int64

# %%
plt.figure(figsize=(10, 8))
plt.pie(view1.values, autopct='%1.1f%%', labels=view1.index)
plt.title('Наличие вида на набережную')
plt.legend(view1.index, loc='upper left');

# %% [markdown]
# Подавляющее большинство домов не имеет вида на набережную.

# %% [markdown]
# 2.2. Изучите распределение этажей домов

# %%
floors1 = house.floors.value_counts()
floors1.head()
# Out:
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# Name: floors, dtype: int64

# %%
plt.figure(figsize=(12, 6))
plt.hist(house.floors)
plt.title('Распределение этажей домов')
plt.xlabel('Этажность')
plt.ylabel('Количество');

# %% [markdown]
# Наибольшее количество одно- и двухэтажных домов

# %% [markdown]
# 2.3. Изучите распределение состояния домов

# %%
condition1 = house.condition.value_counts()
condition1
# Out:
# 3    14031
# 4     5679
# 5     1701
# 2      172
# 1       30
# Name: condition, dtype: int64

# %%
plt.figure(figsize=(12, 6))
plt.hist(house.condition)
plt.title('Распределение состояния домов')
plt.xlabel('Состояние')
plt.ylabel('Количество');

# %% [markdown]
# Подавляющее большинство домов среднего состояния, затем по количеству идут дома с состоянием чуть выше среднего, и на 3-м месте дома с хорошим состоянием.

# %% [markdown]
# ## 3 задача
#
# Исследуйте, какие характеристики недвижимости влияют на стоимость недвижимости, с применением не менее 5 диаграмм из урока.
#
# Анализ сделайте в формате storytelling: дополнить каждый график письменными выводами и наблюдениями.

# %%
sns.scatterplot(data=house,
                x='price',
                y='condition',
                hue='bedrooms',
                palette="crest",
                size='yr_built')
plt.title("Соотношение цена дома vs его состояние")
plt.xlabel("Цена")
plt.ylabel("Состояние");

# %% [markdown]
# Исходя из данного графика видно, что на цену влияет состояние дома и год постройки. Самая высокая цена у домов построенных после 2000 года по состоянию, которое можно оценить как среднее. В подавляющем большинстве это дома до 6 спальных комнат. Самые дешёвые дома, построенные с 1900 по 1940 гг., которые находятся в плохом состоянии.

# %%
sns.scatterplot(data=house,
                x='price',
                y='waterfront',
                hue='yr_built',
                palette="crest")
plt.title("Соотношение цена дома vs близость к воде")
plt.xlabel("Цена")
plt.ylabel("Близость к воде");

# %% [markdown]
# Исходя из данного графика можно увидеть, что близость к воде/морю влияет на стоимость в сторону увеличения, даже дома 1920-1940 года постройки имеют такую же цену, как дома 2000 года постройки и выше, не находящиеся по близости к воде.

# %%
plt.figure(figsize=(12, 6))

sns.relplot(data=house,
            x="price",
            y="floors",
            kind="line",
            height=6,
            aspect=1.67)

plt.title("Влияние этажности на стоимость жилья")
plt.xlabel("Стоимость дома")
plt.ylabel("Количество этажей");

# %% [markdown]
# Из данного графика видно, что в основном дома имеют 2 этажа, этажность не является ключевой в формировании цены. Но если брать самую высокую стоимость домов, то это дома с этажами с 2-х до 3-х.

# %%
house.loc[house['yr_built'] >= 2000, 'age_houseing_group'] = 'Новые'
house.loc[(house['yr_built'] < 2000) & (house['yr_built'] >= 1950), 'age_houseing_group'] = 'Средние'
house.loc[house['yr_built'] < 50, 'age_houseing_group'] = 'Старые'

# %%
plt.subplots(figsize=(12, 6))
sns.histplot(data=house,
             x="price",
             hue="age_houseing_group",
             palette="husl")

plt.title("Распределение стоимости жилья в зависимости от возраста")
plt.xlabel("Цена")
plt.ylabel("Количество");

# %% [markdown]
# Из графика видно, что наибольшую стоимость имеют новые дома, хотя по количеству домов в продаже, лидируют дома среднего возраста. Старые дома имеют самую низкую стоимость.

# %%
plt.subplots(figsize=(12, 6))
sns.scatterplot(data=house,
                x='price',
                y='sqft_living',
                hue='age_houseing_group',
                palette="crest",
                size='yr_renovated')
plt.title("Соотношение цена дома vs его жилая площадь")
plt.xlabel("Цена")
plt.ylabel("Жилая площадь");

# %% [markdown]
# Из графика видно, что жилая площадь сильно влияет на цену, чем больше площадь, тем выше цена. Также видно, что наибольшую цену имеют либо новые дома, либо средние дома, которые были реновированы в 2000 г.
