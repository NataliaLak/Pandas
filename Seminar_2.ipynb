# %% [markdown]
# <a href="https://colab.research.google.com/github/NataliaLak/Google_Colab/blob/main/Seminar_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
df = pd.read_csv("laptop_price.csv", encoding="latin-1")
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# Ноутбуков от какой компании больше всего в наборе
# данных?

# %%
df['Company'].value_counts().head(2)
# Out:
# Dell      297
# Lenovo    297
# Name: Company, dtype: int64

# %% [markdown]
# Какая минимальная и максимальная стоимость у
# ноутбуков в данных?

# %%
df['Price_euros'].min()
# Out:
# 174.0

# %%
df['Price_euros'].max()
# Out:
# 6099.0

# %% [markdown]
# Какой самый дорогой ноутбук в данных?

# %%
df[df['Price_euros'] == df['Price_euros'].max()]['Company'].values
# Out:
# array(['Razer'], dtype=object)

# %% [markdown]
# Выведите все характеристики только по этому ноутбук

# %%
df[df['Price_euros'] == df['Price_euros'].max()]
# Out:
#      laptop_ID Company    Product TypeName  Inches  \
# 196        200   Razer  Blade Pro   Gaming    17.3
#
#                         ScreenResolution                          Cpu   Ram  \
# 196  4K Ultra HD / Touchscreen 3840x2160  Intel Core i7 7820HK 2.9GHz  32GB
#
#       Memory                      Gpu       OpSys  Weight  Price_euros
# 196  1TB SSD  Nvidia GeForce GTX 1080  Windows 10  3.49kg       6099.0

# %% [markdown]
# ### Найдите ноутбуки с самой маленькой диагональю в данных?
# Выведите только следующие характеристики:
# 1. Компания
# 2. Типа ноутбука
# 3. Диагональ
# 4. Стоимость

# %%
df[df["Inches"] == df["Inches"].min()][["Company", "Inches", "TypeName", "Price_euros"]]
# Out:
#      Company  Inches            TypeName  Price_euros
# 50    Lenovo    10.1  2 in 1 Convertible       319.00
# 1082  Lenovo    10.1  2 in 1 Convertible       646.27
# 1114  Lenovo    10.1  2 in 1 Convertible       549.00
# 1126  Lenovo    10.1  2 in 1 Convertible       479.00

# %% [markdown]
# Сколько стоит самый дорогой ноутбук у компании HP?

# %%
df[df["Company"] == "HP"]["Price_euros"].max()
# Out:
# 4389.0

# %% [markdown]
# Как много ноутбуков Ultrabook с 8GB RAM?

# %%
df[(df["TypeName"] == "Ultrabook") & (df["Ram"] == "8GB")].shape[0]
# Out:
# 140

# %% [markdown]
# Найдите сколько таких ультрабуков с 8GB ОЗУ в процентном соотношении
# относительно всех ультрабуков

# %%
u_8gb_count = df[(df["TypeName"] == "Ultrabook") & (df["Ram"] == "8GB")].shape[0]
u_count = df[df["TypeName"] == "Ultrabook"].shape[0]

# %%
u_8gb_count / u_count * 100
# Out:
# 71.42857142857143

# %% [markdown]
# Клиент хочет подобрать ноутбук с 8GB или 16GB ОЗУ на Windows 10 в
# стоимости до 500 евро, сколько у него вариантов?

# %%
df[
    (df["Ram"].isin(["8GB", "16GB"])) &
    (df["OpSys"] == "Windows 10") &
    (df["Price_euros"] <= 500)
].shape[0]
# Out:
# 13

# %% [markdown]
# Клиент хочет подобрать ноутбук от MSI, с видеокартой Nvidia GeForce GTX
# 1050 Ti и главное не с диагональю 15.6. В какой ценовой категории вышли
# подобные ноутбуки

# %%
df1 = df[
      (df["Company"] == "MSI") &
      (df["Gpu"] == "Nvidia GeForce GTX 1050 Ti") &
      (df["Inches"] != 15.6)
  ]
df1["Price_euros"].min(), df1["Price_euros"].max()
# Out:
# (1199.0, 1599.0)

# %% [markdown]
# Найдите самый легкий ноутбук
# Но обратите внимание на тип и представление данных в признаке
# Weight, если что, замените в строке 'kg' на пустую строку через
# метод .str.replace()

# %%
df["Weight"] = df["Weight"].str.replace("kg", '')
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS   1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS   1.34
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   object
#  12  Price_euros       1303 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 132.5+ KB

# %%
df["Weight"] = df["Weight"].astype("float64")
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# ...

# %%
df["Weight"]
# Out:
# 0       1.37
# 1       1.34
# 2       1.86
# 3       1.83
# 4       1.37
#         ...
# 1298    1.80
# 1299    1.30
# 1300    1.50
# 1301    2.19
# 1302    2.20
# Name: Weight, Length: 1303, dtype: float64

# %%
df['Weight'].min()
# Out:
# 0.69

# %%
df[df['Weight'] == df['Weight'].min()]['Company'].values
# Out:
# array(['Lenovo', 'Lenovo', 'Lenovo', 'Lenovo'], dtype=object)
